# %%
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
import numpy as np
import os


chain_dir = '/home/alfonsozapata/montepython_public/chains/miguel4'
chain_root = '2025-06-02_50000_'  

params_to_plot = ['Omega_m', 'H0', 'M', 'Omega_Lambda']

g= plots.getSinglePlotter(chain_dir = chain_dir,analysis_settings={'ignore_rows': 0.3})
g.settings.title_limit_fontsize = 8
g.triangle_plot(chain_root,params=params_to_plot,filled=True,title_limit=1)
# Out:
# /home/alfonsozapata/montepython_public/chains/miguel4/2025-06-02_50000__4.txt
# /home/alfonsozapata/montepython_public/chains/miguel4/2025-06-02_50000__2.txt
# /home/alfonsozapata/montepython_public/chains/miguel4/2025-06-02_50000__1.txt
# /home/alfonsozapata/montepython_public/chains/miguel4/2025-06-02_50000__3.txt
# Removed 0.3 as burn in
# /home/alfonsozapata/anaconda3/lib/python3.9/site-packages/getdist/chains.py:131: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   return loadNumpyTxt.pandas.read_csv(fname, delim_whitespace=True, header=None, dtype=np.float64,
# /home/alfonsozapata/anaconda3/lib/python3.9/site-packages/getdist/chains.py:131: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   return loadNumpyTxt.pandas.read_csv(fname, delim_whitespace=True, header=None, dtype=np.float64,
# ...
